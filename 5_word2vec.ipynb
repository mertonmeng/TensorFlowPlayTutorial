# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'term', 'originated', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.015113
# Nearest to four: guernsey, speleology, mpa, authoritarian, plein, wishing, flattened, conduit,
# Nearest to years: davenport, ligases, glycosides, mckellen, bp, heaped, spink, attracts,
# Nearest to s: distortion, portsmouth, down, culp, icbms, von, blunder, supported,
# Nearest to be: blood, vaughan, nazarbayev, chief, como, satsuma, devourer, causes,
# Nearest to up: rau, informs, pau, witchcraft, lederman, gymnosperms, picatinny, autoerotic,
# Nearest to this: insult, vil, yogi, protestants, transparency, shenzhen, itinerant, collectivity,
# Nearest to are: harvested, bannerman, beatmatching, eleanor, demolish, helmets, spectacular, specialization,
# Nearest to b: acquaintances, teosinte, cushitic, jacinto, postmaster, manuscript, keats, interpolation,
# Nearest to during: sustainable, prerogative, fahd, reflection, wai, edition, toll, ribozymes,
# Nearest to who: hazaras, tenn, amanda, millwall, parthenon, dramatised, hodder, gunpoint,
# Nearest to state: originated, sacrum, sure, reportedly, bea, attacking, clampett, mnemonic,
# Nearest to its: psychoacoustics, paranormal, montferrat, thrusters, broadcasters, yy, fillmore, kept,
# Nearest to may: pathway, banjos, orientations, tinbergen, astana, healthier, abbeys, substandard,
# Nearest to most: wingspan, lineman, rangoon, timbuktu, slashdot, influenced, emulating, renderer,
# Nearest to so: cpu, footy, calvinist, shell, bestows, airbus, brazilians, tithes,
# Nearest to can: yoshitaka, refrigeration, hermeticism, staking, growers, mistrust, worthington, mossad,
# Average loss at step 2000: 4.370340
# Average loss at step 4000: 3.862367
# Average loss at step 6000: 3.785330
# Average loss at step 8000: 3.688331
# Average loss at step 10000: 3.616409
# Nearest to four: six, eight, three, seven, five, two, nine, zero,
# Nearest to years: davenport, attracts, microcebus, mckellen, miles, emblematic, aurangabad, ref,
# Nearest to s: his, rajasthan, responding, ccr, and, or, hobbyist, sextans,
# Nearest to be: have, utensils, been, is, are, was, immediately, somewhat,
# Nearest to up: rau, defraud, informs, macromolecule, bourgeoisie, putting, atat, picatinny,
# Nearest to this: it, the, which, a, cyrix, plasmodium, richmond, an,
# Nearest to are: were, is, have, was, demolish, testimony, elongated, be,
# Nearest to b: teosinte, acquaintances, keats, despotism, bowels, despair, societal, brigadier,
# Nearest to during: sustainable, however, bangla, distortions, qaeda, material, technocracy, edition,
# Nearest to who: he, parthenon, and, perineum, not, rhodesian, hazaras, subtract,
# Nearest to state: sacrum, bea, study, lower, licensed, war, clampett, sure,
# Nearest to its: the, their, his, inklings, guevara, nhl, acclamation, curious,
# Nearest to may: can, pathway, could, tinbergen, co, stipulate, offending, investiture,
# Nearest to most: wreath, oral, flamebait, proposes, renderer, olav, maggie, all,
# Nearest to so: shell, piper, correspondent, calvinist, breweries, just, arteries, i,
# Nearest to can: would, may, could, coerce, will, hermeticism, lynx, acc,
# Average loss at step 12000: 3.605240
# Average loss at step 14000: 3.573927
# Average loss at step 16000: 3.412456
# Average loss at step 18000: 3.456797
# Average loss at step 20000: 3.537694
# Nearest to four: five, eight, three, seven, six, two, nine, zero,
# Nearest to years: attracts, microcebus, davenport, reoccupied, miles, ascetics, indexing, senior,
# Nearest to s: ccr, frazee, culp, trigonometric, the, and, hodgson, chargaff,
# Nearest to be: been, have, refer, was, by, were, is, reliably,
# Nearest to up: rau, defraud, putting, bridges, them, aleksandr, began, bourgeoisie,
# Nearest to this: it, which, the, siddhartha, a, their, plasmodium, cyrix,
# Nearest to are: were, is, have, other, was, hijackers, airmen, testimony,
# Nearest to b: d, teosinte, swiss, societal, despotism, french, italian, relocation,
# Nearest to during: however, sustainable, in, federal, bangla, of, westland, with,
# Nearest to who: he, which, they, she, also, rhodesian, often, perineum,
# Nearest to state: lower, study, licensed, bitwise, attacking, federal, stafford, battled,
# Nearest to its: their, his, the, inklings, colosseum, our, interesting, northridge,
# Nearest to may: can, could, would, might, should, will, to, co,
# Nearest to most: more, many, oral, all, maggie, wreath, ecm, favorably,
# Nearest to so: breweries, piper, faiths, shell, airbus, not, calvinist, correspondent,
# Nearest to can: may, would, could, will, cannot, must, should, might,
# Average loss at step 22000: 3.504625
# Average loss at step 24000: 3.491075
# Average loss at step 26000: 3.484540
# Average loss at step 28000: 3.481108
# Average loss at step 30000: 3.508751
# Nearest to four: five, seven, eight, six, three, two, nine, zero,
# Nearest to years: days, times, reoccupied, attracts, miles, microcebus, year, ascetics,
# Nearest to s: his, hodgson, cuvier, her, ccr, harmonica, benevolence, rajasthan,
# Nearest to be: been, refer, have, were, was, is, phonological, somewhat,
# Nearest to up: them, putting, him, rau, aleksandr, bridges, defraud, refer,
# Nearest to this: which, it, what, there, biographers, tunku, lazuli, siddhartha,
# Nearest to are: were, is, have, spaulding, include, airmen, rask, these,
# Nearest to b: d, teosinte, despotism, societal, foreigners, swiss, unaccented, relocation,
# Nearest to during: after, in, on, however, within, until, with, sustainable,
# Nearest to who: he, she, they, rhodesian, and, often, perineum, which,
# Nearest to state: federal, study, pelvic, country, press, baba, lower, presenter,
# Nearest to its: their, the, his, nsg, northridge, our, exhaustion, inklings,
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to most: more, many, maggie, ecm, oral, all, variance, agnosticism,
# Nearest to so: breweries, ventricle, not, hooks, drills, arma, faiths, correspondent,
# Nearest to can: may, would, could, will, might, cannot, should, must,
# Average loss at step 32000: 3.500497
# Average loss at step 34000: 3.489558
# Average loss at step 36000: 3.454599
# Average loss at step 38000: 3.304806
# Average loss at step 40000: 3.433576
# Nearest to four: six, three, seven, five, eight, two, nine, one,
# Nearest to years: days, times, reoccupied, attracts, months, year, ascetics, microcebus,
# Nearest to s: his, miki, chamorros, stumbled, arion, yakko, harmonica, dubh,
# Nearest to be: been, have, were, refer, was, is, by, being,
# Nearest to up: them, him, putting, out, rau, aleksandr, me, defraud,
# Nearest to this: which, it, that, another, the, some, ustinov, any,
# Nearest to are: were, is, have, but, be, hears, recursive, adrien,
# Nearest to b: d, UNK, despotism, teosinte, conglomerates, unaccented, societal, c,
# Nearest to during: after, on, within, until, throughout, when, around, under,
# Nearest to who: he, often, which, she, also, perineum, realistic, rhodesian,
# Nearest to state: federal, introducing, press, pelvic, lower, distributions, licensed, economy,
# Nearest to its: their, his, the, her, nsg, inklings, our, gasses,
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to most: more, many, variance, oral, hsuan, all, eyewitnesses, favorably,
# Nearest to so: ventricle, not, breweries, arma, cru, hooks, just, piping,
# Nearest to can: could, will, may, would, cannot, must, might, should,
# Average loss at step 42000: 3.431796
# Average loss at step 44000: 3.454993
# Average loss at step 46000: 3.447948
# Average loss at step 48000: 3.357407
# Average loss at step 50000: 3.383809
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to years: days, times, months, reoccupied, year, miles, remini, microcebus,
# Nearest to s: and, goddesses, satrapy, whose, chamorros, deflecting, isbn, benevolence,
# Nearest to be: have, been, refer, was, were, are, being, become,
# Nearest to up: them, out, him, off, rau, aleksandr, putting, me,
# Nearest to this: which, it, another, the, some, zant, he, that,
# Nearest to are: were, is, have, be, those, blondes, these, was,
# Nearest to b: d, despotism, unaccented, x, c, teosinte, sabine, despair,
# Nearest to during: in, after, when, at, within, under, although, throughout,
# Nearest to who: he, she, which, they, often, also, realistic, ruth,
# Nearest to state: federal, firm, distributions, republican, press, pelvic, supplier, curse,
# Nearest to its: their, his, the, nsg, our, coed, exhaustion, gasses,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Nearest to most: more, many, less, some, ecm, bloomfield, oral, hsuan,
# Nearest to so: melissa, arma, if, cru, breweries, ventricle, however, drills,
# Nearest to can: could, may, would, will, must, might, should, cannot,
# Average loss at step 52000: 3.436190
# Average loss at step 54000: 3.425743
# Average loss at step 56000: 3.440825
# Average loss at step 58000: 3.400408
# Average loss at step 60000: 3.392559
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to years: days, times, months, year, reoccupied, remini, hours, miles,
# Nearest to s: vpi, protesters, reaper, exasperation, cuvier, rugrats, marseille, personifications,
# Nearest to be: been, refer, is, become, have, provide, are, was,
# Nearest to up: out, them, off, him, rau, putting, down, aleksandr,
# Nearest to this: it, which, there, some, that, the, zant, delacroix,
# Nearest to are: were, is, have, be, these, those, periodicity, recursive,
# Nearest to b: d, c, n, r, m, f, p, mehmet,
# Nearest to during: after, in, within, although, when, throughout, following, until,
# Nearest to who: he, which, she, also, often, now, never, realistic,
# Nearest to state: federal, department, presenter, introducing, curse, firm, press, study,
# Nearest to its: their, his, the, nsg, her, gasses, our, exhaustion,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Nearest to most: more, many, some, less, ecm, all, priam, use,
# Nearest to so: melissa, if, too, breweries, ventricle, cru, however, seminaries,
# Nearest to can: may, could, would, will, must, cannot, might, should,
# Average loss at step 62000: 3.238619
# Average loss at step 64000: 3.255203
# Average loss at step 66000: 3.403258
# Average loss at step 68000: 3.394360
# Average loss at step 70000: 3.360430
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to years: days, months, hours, times, year, centuries, reoccupied, ascetics,
# Nearest to s: whose, ccr, benevolence, surnames, rugrats, the, miki, karamazov,
# Nearest to be: been, become, is, being, were, refer, was, have,
# Nearest to up: them, out, off, him, putting, back, rau, down,
# Nearest to this: which, it, that, the, palgrave, another, there, some,
# Nearest to are: were, is, have, these, include, although, those, while,
# Nearest to b: d, f, r, m, c, p, n, x,
# Nearest to during: after, in, until, within, throughout, at, under, before,
# Nearest to who: he, she, they, often, which, rhodesian, never, actually,
# Nearest to state: city, press, federal, republican, department, firm, presenter, tradition,
# Nearest to its: their, his, the, her, nsg, our, leszek, whose,
# Nearest to may: can, could, would, will, might, should, must, cannot,
# Nearest to most: more, many, some, less, all, use, quite, variance,
# Nearest to so: too, if, melissa, intertwined, hires, ventricle, anything, when,
# Nearest to can: could, may, would, will, cannot, should, might, must,
# Average loss at step 72000: 3.373595
# Average loss at step 74000: 3.349340
# Average loss at step 76000: 3.316042
# Average loss at step 78000: 3.350584
# Average loss at step 80000: 3.375544
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to years: days, months, times, hours, year, centuries, reoccupied, weeks,
# Nearest to s: korfball, hodgson, ccr, stretches, excel, miki, subatomic, frazee,
# Nearest to be: been, have, refer, being, become, was, are, is,
# Nearest to up: out, off, them, him, down, back, putting, rau,
# Nearest to this: which, it, what, another, the, there, that, he,
# Nearest to are: were, have, is, these, include, those, being, although,
# Nearest to b: d, c, f, p, m, x, r, deity,
# Nearest to during: after, in, throughout, until, when, although, before, within,
# Nearest to who: he, actually, she, often, they, which, never, rhodesian,
# Nearest to state: city, press, firm, states, federal, statement, zap, republican,
# Nearest to its: their, his, the, her, our, tenniel, nsg, coed,
# Nearest to may: can, could, might, would, will, should, must, cannot,
# Nearest to most: more, many, some, less, ecm, priam, quite, all,
# Nearest to so: if, misconception, too, melissa, intertwined, cru, ventricle, queries,
# Nearest to can: could, may, would, will, cannot, must, might, should,
# Average loss at step 82000: 3.404185
# Average loss at step 84000: 3.410764
# Average loss at step 86000: 3.388310
# Average loss at step 88000: 3.353185
# Average loss at step 90000: 3.369378
# Nearest to four: five, three, seven, eight, six, two, nine, one,
# Nearest to years: days, months, hours, year, times, centuries, weeks, ascetics,
# Nearest to s: his, benevolence, cuvier, miki, exasperation, culp, whose, my,
# Nearest to be: been, refer, become, have, being, was, is, receive,
# Nearest to up: out, off, them, him, down, back, together, putting,
# Nearest to this: which, it, another, some, the, what, ustinov, there,
# Nearest to are: were, is, include, have, these, contain, while, although,
# Nearest to b: c, d, p, r, f, despotism, n, l,
# Nearest to during: in, after, throughout, until, although, before, while, at,
# Nearest to who: he, also, often, she, which, they, actually, never,
# Nearest to state: city, republican, firm, cambridge, zap, press, federal, comiskey,
# Nearest to its: their, his, her, the, whose, our, your, nsg,
# Nearest to may: can, could, might, would, should, must, will, cannot,
# Nearest to most: more, many, less, some, throughout, use, all, ecm,
# Nearest to so: if, too, although, intertwined, piping, dipped, pall, worse,
# Nearest to can: could, may, will, must, would, might, cannot, should,
# Average loss at step 92000: 3.396095
# Average loss at step 94000: 3.254882
# Average loss at step 96000: 3.355016
# Average loss at step 98000: 3.238538
# Average loss at step 100000: 3.356522
# Nearest to four: five, six, seven, eight, nine, three, two, zero,
# Nearest to years: days, months, year, times, hours, centuries, seconds, decades,
# Nearest to s: his, whose, protesters, juan, ccr, frazee, rossetti, fulfills,
# Nearest to be: been, refer, become, have, being, is, are, satsuma,
# Nearest to up: out, off, them, back, him, together, rau, down,
# Nearest to this: it, which, another, what, there, meditation, he, the,
# Nearest to are: were, have, include, is, although, while, those, these,
# Nearest to b: d, teosinte, abbott, unaccented, despotism, negotiators, german, falsehoods,
# Nearest to during: in, after, throughout, until, before, within, through, at,
# Nearest to who: he, actually, she, also, often, that, which, never,
# Nearest to state: city, press, republican, firm, cambridge, zap, comiskey, statement,
# Nearest to its: their, his, the, her, our, whose, espoused, monopolist,
# Nearest to may: can, could, might, should, would, must, will, cannot,
# Nearest to most: more, less, throughout, especially, quite, many, use, ecm,
# Nearest to so: when, thus, too, cru, dipped, mutinied, intertwined, then,
# Nearest to can: could, may, will, must, would, cannot, should, might,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
